# %%
# Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy import stats

# %%
# Importing datasets

# Loading the data for study 1 and looking at head
df1 = pd.read_csv('data/data_study1.csv')

# Setting option to display unlimited number of columns
pd.set_option('display.max_columns', None)

df1.head()
# Out:
#   Unnamed: 0         UID  Country     Sex   Age  Edu_high  Edu_low  Pol_Ori  \
# 0  iceland.1  Iceland::1  Iceland    male  33.0       1.0      0.0      4.2
# 1  iceland.2  Iceland::2  Iceland    male  28.0       1.0      0.0      4.2
# 2  iceland.3  Iceland::3  Iceland  female  35.0       0.0      1.0      NaN
# 3  iceland.4  Iceland::4  Iceland    male  55.0       1.0      0.0      5.0
# 4  iceland.5  Iceland::5  Iceland    male  52.0       0.0      1.0      5.8
#
#     ZmeanPO       ZPO  CMQ_1  CMQ_2  CMQ_3  CMQ_4  CMQ_5  CM4x  CM5x  CT_left  \
# 0  1.064809 -0.453397   11.0   10.0    1.0    7.0    1.0  5.00   6.0      7.0
# 1  1.064809 -0.453397    7.0    7.0    4.0    3.0    5.0  4.75   5.2      1.0
# 2  1.064809       NaN    8.0    7.0    4.0    9.0    3.0  6.00   6.2      5.5
# 3  1.064809 -0.015141    5.0    8.0    6.0    4.0    3.0  4.50   5.2      4.0
# 4  1.064809  0.423114    8.0    6.0    5.0    7.0    6.0  6.50   6.4      5.5
#
#    CT_right  CT_neutral  Winner_state CHES_version  lrgen  lrecon  galtan  \
# 0       4.0         1.0           NaN          NaN    NaN     NaN     NaN
# 1       1.0         2.5           0.0          NaN    NaN     NaN     NaN
# 2       5.5         4.0           NaN          NaN    NaN     NaN     NaN
# 3       1.0         1.0           1.0          NaN    NaN     NaN     NaN
# 4       4.0         4.0           0.0          NaN    NaN     NaN     NaN
#
#    zlrgen  zlrecon  zgaltan  mean_lrgen  mean_lrecon  mean_galtan  \
# 0     NaN      NaN      NaN         NaN          NaN          NaN
# 1     NaN      NaN      NaN         NaN          NaN          NaN
# 2     NaN      NaN      NaN         NaN          NaN          NaN
# 3     NaN      NaN      NaN         NaN          NaN          NaN
# 4     NaN      NaN      NaN         NaN          NaN          NaN
#
#    zmean_lrgen  zmean_lrecon  zmean_galtan  lrgengov  lrecongov  galtangov  \
# 0          NaN           NaN           NaN       NaN        NaN        NaN
# 1          NaN           NaN           NaN       NaN        NaN        NaN
# 2          NaN           NaN           NaN       NaN        NaN        NaN
# 3          NaN           NaN           NaN       NaN        NaN        NaN
# 4          NaN           NaN           NaN       NaN        NaN        NaN
#
#         CPO
# 0 -0.827639
# 1 -0.827639
# 2       NaN
# 3 -0.027639
# 4  0.772361

# %%
# Loading the data from the second study

df2 = pd.read_csv('data/data_study2.csv')

df2.head()
# Out:
#    Unnamed: 0   Weights     Sex        Age Country  Pol_Ori  CMQ_1  CMQ_2  \
# 0           1  1.532339    Male  18.916667  Sweden      5.0    8.0    8.0
# 1           2  0.997387    Male  25.750000  Sweden     11.0    NaN    NaN
# 2           3  6.050884  Female  19.916667  Sweden     11.0   11.0   11.0
# 3           4  1.838405    Male  62.750000  Sweden      8.0    NaN    NaN
# 4           5  0.997387    Male  30.916667  Sweden      5.0   11.0    7.0
#
#    CMQ_3  CMQ_4  CMQ_5  Edu_low  Edu_high  Winner_state CHES_version  \
# 0    4.0    6.0    7.0      0.0       0.0           1.0       CHES17
# 1    NaN    NaN    NaN      0.0       1.0           1.0       CHES17
# 2   11.0    9.0   11.0      0.0       0.0           0.0       CHES17
# 3    NaN    NaN    NaN      0.0       0.0           1.0       CHES17
# 4    9.0    6.0   11.0      0.0       1.0           1.0       CHES17
#
#       lrgen    lrecon    galtan    zlrgen   zlrecon   zgaltan       ZPO  \
# 0  3.888889  3.470588  4.411765 -0.799850 -0.780204 -0.336897 -0.449278
# 1  7.944445  8.411765  5.888889  0.837842  1.306571  0.191618  1.617198
# 2  8.000000  5.941176  8.944445  0.860276  0.263184  1.284895  1.617198
# 3  7.944445  8.411765  5.888889  0.837842  1.306571  0.191618  0.583960
# 4  3.888889  3.470588  4.411765 -0.799850 -0.780204 -0.336897 -0.449278
#
#     ZmeanPO   CM4x  CM5x       CPO
# 0  1.062604   6.25   6.6 -1.304476
# 1  1.062604    NaN   NaN  4.695524
# 2  1.062604  10.50  10.6  4.695524
# 3  1.062604    NaN   NaN  1.695524
# 4  1.062604   8.25   8.8 -1.304476

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40954 entries, 0 to 40953
# Data columns (total 38 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    40954 non-null  object
#  1   UID           40954 non-null  object
#  2   Country       40954 non-null  object
#  3   Sex           37629 non-null  object
#  4   Age           37555 non-null  float64
#  5   Edu_high      31414 non-null  float64
#  6   Edu_low       31414 non-null  float64
#  7   Pol_Ori       38145 non-null  float64
#  8   ZmeanPO       40954 non-null  float64
#  9   ZPO           38145 non-null  float64
#  10  CMQ_1         33670 non-null  float64
#  11  CMQ_2         33641 non-null  float64
#  12  CMQ_3         33592 non-null  float64
#  13  CMQ_4         33447 non-null  float64
#  14  CMQ_5         33505 non-null  float64
#  15  CM4x          33195 non-null  float64
#  16  CM5x          33152 non-null  float64
#  17  CT_left       29555 non-null  float64
#  18  CT_right      29639 non-null  float64
#  19  CT_neutral    29141 non-null  float64
#  20  Winner_state  29184 non-null  float64
#  21  CHES_version  38385 non-null  object
#  22  lrgen         27371 non-null  float64
#  23  lrecon        27371 non-null  float64
#  24  galtan        27371 non-null  float64
#  25  zlrgen        27371 non-null  float64
#  26  zlrecon       27371 non-null  float64
#  27  zgaltan       27371 non-null  float64
#  28  mean_lrgen    38385 non-null  float64
#  29  mean_lrecon   38385 non-null  float64
#  30  mean_galtan   38385 non-null  float64
#  31  zmean_lrgen   38385 non-null  float64
#  32  zmean_lrecon  38385 non-null  float64
#  33  zmean_galtan  38385 non-null  float64
#  34  lrgengov      38030 non-null  float64
#  35  lrecongov     38030 non-null  float64
#  36  galtangov     38030 non-null  float64
#  37  CPO           38145 non-null  float64
# dtypes: float64(33), object(5)
# memory usage: 11.9+ MB

# %%
# Dropping old index columns
df1.drop(columns='Unnamed: 0', axis=1, inplace=True)

# Sanity check
df1.head()
# Out:
#           UID  Country     Sex   Age  Edu_high  Edu_low  Pol_Ori   ZmeanPO  \
# 0  Iceland::1  Iceland    male  33.0       1.0      0.0      4.2  1.064809
# 1  Iceland::2  Iceland    male  28.0       1.0      0.0      4.2  1.064809
# 2  Iceland::3  Iceland  female  35.0       0.0      1.0      NaN  1.064809
# 3  Iceland::4  Iceland    male  55.0       1.0      0.0      5.0  1.064809
# 4  Iceland::5  Iceland    male  52.0       0.0      1.0      5.8  1.064809
#
#         ZPO  CMQ_1  CMQ_2  CMQ_3  CMQ_4  CMQ_5  CM4x  CM5x  CT_left  CT_right  \
# 0 -0.453397   11.0   10.0    1.0    7.0    1.0  5.00   6.0      7.0       4.0
# 1 -0.453397    7.0    7.0    4.0    3.0    5.0  4.75   5.2      1.0       1.0
# 2       NaN    8.0    7.0    4.0    9.0    3.0  6.00   6.2      5.5       5.5
# 3 -0.015141    5.0    8.0    6.0    4.0    3.0  4.50   5.2      4.0       1.0
# 4  0.423114    8.0    6.0    5.0    7.0    6.0  6.50   6.4      5.5       4.0
#
#    CT_neutral  Winner_state CHES_version  lrgen  lrecon  galtan  zlrgen  \
# 0         1.0           NaN          NaN    NaN     NaN     NaN     NaN
# 1         2.5           0.0          NaN    NaN     NaN     NaN     NaN
# 2         4.0           NaN          NaN    NaN     NaN     NaN     NaN
# 3         1.0           1.0          NaN    NaN     NaN     NaN     NaN
# 4         4.0           0.0          NaN    NaN     NaN     NaN     NaN
#
#    zlrecon  zgaltan  mean_lrgen  mean_lrecon  mean_galtan  zmean_lrgen  \
# 0      NaN      NaN         NaN          NaN          NaN          NaN
# 1      NaN      NaN         NaN          NaN          NaN          NaN
# 2      NaN      NaN         NaN          NaN          NaN          NaN
# 3      NaN      NaN         NaN          NaN          NaN          NaN
# 4      NaN      NaN         NaN          NaN          NaN          NaN
#
#    zmean_lrecon  zmean_galtan  lrgengov  lrecongov  galtangov       CPO
# 0           NaN           NaN       NaN        NaN        NaN -0.827639
# 1           NaN           NaN       NaN        NaN        NaN -0.827639
# 2           NaN           NaN       NaN        NaN        NaN       NaN
# 3           NaN           NaN       NaN        NaN        NaN -0.027639
# 4           NaN           NaN       NaN        NaN        NaN  0.772361

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40954 entries, 0 to 40953
# Data columns (total 37 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UID           40954 non-null  object
#  1   Country       40954 non-null  object
#  2   Sex           37629 non-null  object
#  3   Age           37555 non-null  float64
#  4   Edu_high      31414 non-null  float64
#  5   Edu_low       31414 non-null  float64
#  6   Pol_Ori       38145 non-null  float64
#  7   ZmeanPO       40954 non-null  float64
#  8   ZPO           38145 non-null  float64
#  9   CMQ_1         33670 non-null  float64
#  10  CMQ_2         33641 non-null  float64
#  11  CMQ_3         33592 non-null  float64
#  12  CMQ_4         33447 non-null  float64
#  13  CMQ_5         33505 non-null  float64
#  14  CM4x          33195 non-null  float64
#  15  CM5x          33152 non-null  float64
#  16  CT_left       29555 non-null  float64
#  17  CT_right      29639 non-null  float64
#  18  CT_neutral    29141 non-null  float64
#  19  Winner_state  29184 non-null  float64
#  20  CHES_version  38385 non-null  object
#  21  lrgen         27371 non-null  float64
#  22  lrecon        27371 non-null  float64
#  23  galtan        27371 non-null  float64
#  24  zlrgen        27371 non-null  float64
#  25  zlrecon       27371 non-null  float64
#  26  zgaltan       27371 non-null  float64
#  27  mean_lrgen    38385 non-null  float64
#  28  mean_lrecon   38385 non-null  float64
#  29  mean_galtan   38385 non-null  float64
#  30  zmean_lrgen   38385 non-null  float64
#  31  zmean_lrecon  38385 non-null  float64
#  32  zmean_galtan  38385 non-null  float64
#  33  lrgengov      38030 non-null  float64
#  34  lrecongov     38030 non-null  float64
#  35  galtangov     38030 non-null  float64
#  36  CPO           38145 non-null  float64
# dtypes: float64(33), object(4)
# memory usage: 11.6+ MB

# %%
df2.drop(columns='Unnamed: 0', axis=1, inplace=True)

# Sanity check
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89576 entries, 0 to 89575
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weights       66596 non-null  float64
#  1   Sex           71913 non-null  object
#  2   Age           72988 non-null  float64
#  3   Country       89576 non-null  object
#  4   Pol_Ori       73636 non-null  float64
#  5   CMQ_1         53437 non-null  float64
#  6   CMQ_2         52895 non-null  float64
#  7   CMQ_3         52890 non-null  float64
#  8   CMQ_4         52718 non-null  float64
#  9   CMQ_5         52716 non-null  float64
#  10  Edu_low       89507 non-null  float64
#  11  Edu_high      89507 non-null  float64
#  12  Winner_state  65087 non-null  float64
#  13  CHES_version  89576 non-null  object
#  14  lrgen         55414 non-null  float64
#  15  lrecon        55414 non-null  float64
#  16  galtan        55414 non-null  float64
#  17  zlrgen        55414 non-null  float64
#  18  zlrecon       55414 non-null  float64
#  19  zgaltan       55414 non-null  float64
#  20  ZPO           73636 non-null  float64
#  21  ZmeanPO       89576 non-null  float64
#  22  CM4x          51759 non-null  float64
#  23  CM5x          51691 non-null  float64
#  24  CPO           73636 non-null  float64
# dtypes: float64(22), object(3)
# memory usage: 17.1+ MB

# %%
# Reducing columns
df1_small = df1[['Country','Sex','Age','Edu_high','Edu_low','Pol_Ori','CMQ_1',
                'CMQ_2','CMQ_3','CMQ_4','CMQ_5','CM4x','CM5x','Winner_state','lrgen',
                'lrecon','galtan']]

df2_small = df2[['Country','Sex','Age','Edu_high','Edu_low','Pol_Ori','CMQ_1',
                'CMQ_2','CMQ_3','CMQ_4','CMQ_5','CM4x','CM5x','Winner_state','lrgen',
                'lrecon','galtan']]

# %%
# Sanity check

df1_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40954 entries, 0 to 40953
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       40954 non-null  object
#  1   Sex           37629 non-null  object
#  2   Age           37555 non-null  float64
#  3   Edu_high      31414 non-null  float64
#  4   Edu_low       31414 non-null  float64
#  5   Pol_Ori       38145 non-null  float64
#  6   CMQ_1         33670 non-null  float64
#  7   CMQ_2         33641 non-null  float64
#  8   CMQ_3         33592 non-null  float64
#  9   CMQ_4         33447 non-null  float64
#  10  CMQ_5         33505 non-null  float64
#  11  CM4x          33195 non-null  float64
#  12  CM5x          33152 non-null  float64
#  13  Winner_state  29184 non-null  float64
#  14  lrgen         27371 non-null  float64
#  15  lrecon        27371 non-null  float64
#  16  galtan        27371 non-null  float64
# dtypes: float64(15), object(2)
# memory usage: 5.3+ MB

# %%
df2_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89576 entries, 0 to 89575
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       89576 non-null  object
#  1   Sex           71913 non-null  object
#  2   Age           72988 non-null  float64
#  3   Edu_high      89507 non-null  float64
#  4   Edu_low       89507 non-null  float64
#  5   Pol_Ori       73636 non-null  float64
#  6   CMQ_1         53437 non-null  float64
#  7   CMQ_2         52895 non-null  float64
#  8   CMQ_3         52890 non-null  float64
#  9   CMQ_4         52718 non-null  float64
#  10  CMQ_5         52716 non-null  float64
#  11  CM4x          51759 non-null  float64
#  12  CM5x          51691 non-null  float64
#  13  Winner_state  65087 non-null  float64
#  14  lrgen         55414 non-null  float64
#  15  lrecon        55414 non-null  float64
#  16  galtan        55414 non-null  float64
# dtypes: float64(15), object(2)
# memory usage: 11.6+ MB

# %%
df_full = pd.concat([df1_small, df2_small])

df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130530 entries, 0 to 89575
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Country       130530 non-null  object
#  1   Sex           109542 non-null  object
#  2   Age           110543 non-null  float64
#  3   Edu_high      120921 non-null  float64
#  4   Edu_low       120921 non-null  float64
#  5   Pol_Ori       111781 non-null  float64
#  6   CMQ_1         87107 non-null   float64
#  7   CMQ_2         86536 non-null   float64
#  8   CMQ_3         86482 non-null   float64
#  9   CMQ_4         86165 non-null   float64
#  10  CMQ_5         86221 non-null   float64
#  11  CM4x          84954 non-null   float64
#  12  CM5x          84843 non-null   float64
#  13  Winner_state  94271 non-null   float64
#  14  lrgen         82785 non-null   float64
#  15  lrecon        82785 non-null   float64
#  16  galtan        82785 non-null   float64
# dtypes: float64(15), object(2)
# memory usage: 17.9+ MB

# %%
gdp_df = pd.read_csv('data/gdp_data.csv')

gdp_df.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.112502e+10  2.161623e+10  2.350628e+10  2.804836e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.044764e+10  1.117321e+10  1.199053e+10  1.272769e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965          1966          1967          1968  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.592067e+10  2.947210e+10  3.201437e+10  3.326951e+10  3.632779e+10
# 2  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09
# 3  1.389811e+10  1.492979e+10  1.591084e+10  1.451058e+10  1.496824e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            1969          1970          1971          1972          1973  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  4.163897e+10  4.462989e+10  4.917337e+10  5.312346e+10  6.948272e+10
# 2  1.408889e+09  1.748887e+09  1.831109e+09  1.595555e+09  1.733333e+09
# 3  1.697932e+10  2.359616e+10  2.093636e+10  2.538617e+10  3.197559e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            1974          1975          1976          1977          1978  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  8.538065e+10  9.083543e+10  9.021275e+10  1.022410e+11  1.160850e+11
# 2  2.155555e+09  2.366667e+09  2.555556e+09  2.953333e+09  3.300000e+09
# 3  4.441668e+10  5.166719e+10  6.235162e+10  6.559512e+10  7.149650e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            1979          1980          1981          1982          1983  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  1.342570e+11  1.712180e+11  1.758590e+11  1.680960e+11  1.755650e+11
# 2  3.697940e+09  3.641723e+09  3.478788e+09           NaN           NaN
# 3  8.894834e+10  1.124390e+11  2.113380e+11  1.874490e+11  1.383840e+11
# 4           NaN  5.930503e+09  5.550483e+09  5.550483e+09  5.784342e+09
#
#            1984          1985          1986          1987          1988  \
# 0           NaN           NaN  4.055866e+08  4.877095e+08  5.966480e+08
# 1  1.606470e+11  1.367590e+11  1.530500e+11  1.866580e+11  2.047660e+11
# 2           NaN           NaN           NaN           NaN           NaN
# 3  1.145160e+11  1.167770e+11  1.078870e+11  1.107290e+11  1.094390e+11
# 4  6.131475e+09  7.554065e+09  7.072536e+09  8.084412e+09  8.769837e+09
#
#            1989          1990          1991          1992          1993  \
# 0  6.955307e+08  7.648045e+08  8.720670e+08  9.586592e+08  1.083240e+09
# 1  2.182420e+11  2.540620e+11  2.768570e+11  2.460880e+11  2.429260e+11
# 2           NaN           NaN           NaN           NaN           NaN
# 3  1.022550e+11  1.223870e+11  1.180400e+11  1.188930e+11  9.927218e+10
# 4  1.020178e+10  1.122952e+10  1.270456e+10  1.511435e+10  1.105194e+10
#
#            1994          1995          1996          1997          1998  \
# 0  1.245810e+09  1.320670e+09  1.379888e+09  1.531844e+09  1.665363e+09
# 1  2.396110e+11  2.703270e+11  2.694910e+11  2.834460e+11  2.666520e+11
# 2           NaN           NaN           NaN           NaN           NaN
# 3  8.663640e+10  1.086910e+11  1.262870e+11  1.276020e+11  1.306780e+11
# 4  3.390500e+09  5.561222e+09  7.526964e+09  7.648377e+09  6.506230e+09
#
#            1999          2000          2001          2002          2003  \
# 0  1.722905e+09  1.873184e+09  1.896648e+09  1.962011e+09  2.044134e+09
# 1  2.630250e+11  2.847590e+11  2.596430e+11  2.665290e+11  3.541770e+11
# 2           NaN           NaN           NaN  3.854235e+09  4.539497e+09
# 3  1.380860e+11  1.409460e+11  1.485300e+11  1.772010e+11  2.052140e+11
# 4  6.152923e+09  9.129595e+09  8.936079e+09  1.528559e+10  1.781270e+10
#
#            2004          2005          2006          2007          2008  \
# 0  2.254749e+09  2.359777e+09  2.469832e+09  2.677654e+09  2.843017e+09
# 1  4.404820e+11  5.139420e+11  5.775870e+11  6.628680e+11  7.105360e+11
# 2  5.220825e+09  6.226199e+09  6.971383e+09  9.715765e+09  1.024977e+10
# 3  2.542650e+11  3.108900e+11  3.969210e+11  4.654860e+11  5.677910e+11
# 4  2.355206e+10  3.697090e+10  5.238103e+10  6.526642e+10  8.853866e+10
#
#            2009          2010          2011          2012          2013  \
# 0  2.553631e+09  2.453631e+09  2.637989e+09  2.615084e+09  2.727933e+09
# 1  7.219010e+11  8.635200e+11  9.678250e+11  9.753550e+11  9.859870e+11
# 2  1.215484e+10  1.563384e+10  1.819041e+10  2.020357e+10  2.056449e+10
# 3  5.083630e+11  5.985220e+11  6.820160e+11  7.375890e+11  8.339480e+11
# 4  7.030720e+10  8.169953e+10  1.094370e+11  1.249980e+11  1.334020e+11
#
#            2014          2015          2016          2017          2018  \
# 0  2.791061e+09  2.963128e+09  2.983799e+09  3.092179e+09  3.276188e+09
# 1  1.006530e+12  9.273480e+11  8.851760e+11  1.021040e+12  1.007200e+12
# 2  2.055058e+10  1.999814e+10  1.801955e+10  1.889635e+10  1.841886e+10
# 3  8.943220e+11  7.686450e+11  6.913630e+11  6.848990e+11  7.670260e+11
# 4  1.372440e+11  8.721930e+10  4.984049e+10  6.897277e+10  7.779294e+10
#
#            2019          2020          2021          2022
# 0  3.395794e+09  2.610039e+09  3.126019e+09           NaN
# 1  1.000830e+12  9.275930e+11  1.082000e+12  1.169480e+12
# 2  1.890450e+10  2.014345e+10  1.458314e+10           NaN
# 3  8.225380e+11  7.864600e+11  8.444600e+11  8.778630e+11
# 4  6.930911e+10  5.024137e+10  6.568544e+10  1.067140e+11

# %%
gdp_df = gdp_df[['Country Name','2017']]

gdp_df.head()
# Out:
#                   Country Name          2017
# 0                        Aruba  3.092179e+09
# 1  Africa Eastern and Southern  1.021040e+12
# 2                  Afghanistan  1.889635e+10
# 3   Africa Western and Central  6.848990e+11
# 4                       Angola  6.897277e+10

# %%
country_list = list(df_full['Country'].unique())

country_list
# Out:
# ['Iceland',
#  'Belgium, FR',
#  'Bosnia',
#  'Brazil',
#  'Switzerland, FR',
#  'Switzerland, GE',
#  'Croatia',
#  'Czech Republic',
#  'France',
#  'Greece',
#  'Hungary',
#  'Italy',
#  'Macedonia',
#  'Netherlands',
#  'Poland',
#  'Serbia',
#  'Spain',
#  'Turkey',
#  'Norway',
#  'Germany',
#  'Israel',
#  'Portugal',
#  'Romania',
#  'UK',
#  'Sweden',
#  'Denmark',
#  'Belgium-Wallonia',
#  'Belgium-Flanders',
#  'Austria']

# %%
exceptions = []
for country in country_list:
    if country in list(gdp_df['Country Name'].unique()):
        print(country, gdp_df[gdp_df['Country Name'] == country][str(2017)])
    else:
        exceptions.append(country)

print(exceptions)
# Out:
# Iceland 114    2.472829e+10
# Name: 2017, dtype: float64
# Brazil 29    2.063510e+12
# Name: 2017, dtype: float64
# Croatia 99    5.593748e+10
# Name: 2017, dtype: float64
# France 77    2.595150e+12
# Name: 2017, dtype: float64
# Greece 89    1.998440e+11
# Name: 2017, dtype: float64
# Hungary 101    1.431120e+11
# Name: 2017, dtype: float64
# Italy 116    1.961800e+12
# Name: 2017, dtype: float64
# Netherlands 176    8.338700e+11
# Name: 2017, dtype: float64
# Poland 190    5.246410e+11
# Name: 2017, dtype: float64
# Serbia 214    4.417908e+10
# Name: 2017, dtype: float64
# Spain 70    1.313250e+12
# Name: 2017, dtype: float64
# Norway 177    4.017450e+11
# Name: 2017, dtype: float64
# Germany 55    3.690850e+12
# Name: 2017, dtype: float64
# Israel 115    3.582450e+11
# Name: 2017, dtype: float64
# Portugal 194    2.213580e+11
# Name: 2017, dtype: float64
# Romania 201    2.101470e+11
# Name: 2017, dtype: float64
# Sweden 223    5.410190e+11
# Name: 2017, dtype: float64
# Denmark 58    3.321210e+11
# Name: 2017, dtype: float64
# Austria 14    4.172610e+11
# Name: 2017, dtype: float64
# ['Belgium, FR', 'Bosnia', 'Switzerland, FR', 'Switzerland, GE', 'Czech Republic', 'Macedonia', 'Turkey', 'UK', 'Belgium-Wallonia', 'Belgium-Flanders']

# %%
country_dict = {}

country_dict['Belgium, FR'] = 'Belgium'
country_dict['Belgium-Wallonia'] = 'Belgium'
country_dict['Belgium-Flanders'] = 'Belgium'
country_dict['Bosnia'] = 'Bosnia and Herzegovina'
country_dict['Switzerland, FR'] = 'Switzerland'
country_dict['Switzerland, GE'] = 'Switzerland'
country_dict['Czech Republic'] = 'Czechia'
country_dict['Macedonia'] = 'North Macedonia'
country_dict['Turkey'] = 'Turkiye'
country_dict['UK'] = 'United Kingdom'

country_dict
# Out:
# {'Belgium, FR': 'Belgium',
#  'Belgium-Wallonia': 'Belgium',
#  'Belgium-Flanders': 'Belgium',
#  'Bosnia': 'Bosnia and Herzegovina',
#  'Switzerland, FR': 'Switzerland',
#  'Switzerland, GE': 'Switzerland',
#  'Czech Republic': 'Czechia',
#  'Macedonia': 'North Macedonia',
#  'Turkey': 'Turkiye',
#  'UK': 'United Kingdom'}

# %%
pd.options.mode.chained_assignment = None  # default='warn'

for old, new in country_dict.items():
    df_full['Country'][df_full['Country'] == old] = new

# sanity check
df_full['Country'].unique()
# Out:
# array(['Iceland', 'Belgium', 'Bosnia and Herzegovina', 'Brazil',
#        'Switzerland', 'Croatia', 'Czechia', 'France', 'Greece', 'Hungary',
#        'Italy', 'North Macedonia', 'Netherlands', 'Poland', 'Serbia',
#        'Spain', 'Turkiye', 'Norway', 'Germany', 'Israel', 'Portugal',
#        'Romania', 'United Kingdom', 'Sweden', 'Denmark', 'Austria'],
#       dtype=object)

# %%
df_full = pd.merge(df_full, gdp_df, how='left', left_on='Country', right_on='Country Name')

df_full.head()
# Out:
#    Country     Sex   Age  Edu_high  Edu_low  Pol_Ori  CMQ_1  CMQ_2  CMQ_3  \
# 0  Iceland    male  33.0       1.0      0.0      4.2   11.0   10.0    1.0
# 1  Iceland    male  28.0       1.0      0.0      4.2    7.0    7.0    4.0
# 2  Iceland  female  35.0       0.0      1.0      NaN    8.0    7.0    4.0
# 3  Iceland    male  55.0       1.0      0.0      5.0    5.0    8.0    6.0
# 4  Iceland    male  52.0       0.0      1.0      5.8    8.0    6.0    5.0
#
#    CMQ_4  CMQ_5  CM4x  CM5x  Winner_state  lrgen  lrecon  galtan Country Name  \
# 0    7.0    1.0  5.00   6.0           NaN    NaN     NaN     NaN      Iceland
# 1    3.0    5.0  4.75   5.2           0.0    NaN     NaN     NaN      Iceland
# 2    9.0    3.0  6.00   6.2           NaN    NaN     NaN     NaN      Iceland
# 3    4.0    3.0  4.50   5.2           1.0    NaN     NaN     NaN      Iceland
# 4    7.0    6.0  6.50   6.4           0.0    NaN     NaN     NaN      Iceland
#
#            2017
# 0  2.472829e+10
# 1  2.472829e+10
# 2  2.472829e+10
# 3  2.472829e+10
# 4  2.472829e+10

# %%
df_full.rename(columns={'2017':'2017_GDP'}, inplace=True)

# %%
df_full.drop(columns='Country Name', inplace=True)
df_full.head()
# Out:
#    Country     Sex   Age  Edu_high  Edu_low  Pol_Ori  CMQ_1  CMQ_2  CMQ_3  \
# 0  Iceland    male  33.0       1.0      0.0      4.2   11.0   10.0    1.0
# 1  Iceland    male  28.0       1.0      0.0      4.2    7.0    7.0    4.0
# 2  Iceland  female  35.0       0.0      1.0      NaN    8.0    7.0    4.0
# 3  Iceland    male  55.0       1.0      0.0      5.0    5.0    8.0    6.0
# 4  Iceland    male  52.0       0.0      1.0      5.8    8.0    6.0    5.0
#
#    CMQ_4  CMQ_5  CM4x  CM5x  Winner_state  lrgen  lrecon  galtan      2017_GDP
# 0    7.0    1.0  5.00   6.0           NaN    NaN     NaN     NaN  2.472829e+10
# 1    3.0    5.0  4.75   5.2           0.0    NaN     NaN     NaN  2.472829e+10
# 2    9.0    3.0  6.00   6.2           NaN    NaN     NaN     NaN  2.472829e+10
# 3    4.0    3.0  4.50   5.2           1.0    NaN     NaN     NaN  2.472829e+10
# 4    7.0    6.0  6.50   6.4           0.0    NaN     NaN     NaN  2.472829e+10

# %%
df_full.groupby('Country')['2017_GDP'].mean()
# Out:
# Country
# Austria                   4.172610e+11
# Belgium                   5.027650e+11
# Bosnia and Herzegovina    1.832638e+10
# Brazil                    2.063510e+12
# Croatia                   5.593748e+10
# Czechia                   2.186290e+11
# Denmark                   3.321210e+11
# France                    2.595150e+12
# Germany                   3.690850e+12
# Greece                    1.998440e+11
# Hungary                   1.431120e+11
# Iceland                   2.472829e+10
# Israel                    3.582450e+11
# Italy                     1.961800e+12
# Netherlands               8.338700e+11
# North Macedonia           1.130707e+10
# Norway                    4.017450e+11
# Poland                    5.246410e+11
# Portugal                  2.213580e+11
# Romania                   2.101470e+11
# Serbia                    4.417908e+10
# Spain                     1.313250e+12
# Sweden                    5.410190e+11
# Switzerland               6.952010e+11
# Turkiye                   8.589890e+11
# United Kingdom            2.683490e+12
# Name: 2017_GDP, dtype: float64

# %%
unemployment = pd.read_csv('data/unemployment.csv')

unemployment.head()
# Out:
#                   Country Name       2017       2018
# 0                        Aruba        NaN        NaN
# 1  Africa Eastern and Southern   6.940365   6.913046
# 2                  Afghanistan  11.180000  11.110000
# 3   Africa Western and Central   4.140484   4.201599
# 4                       Angola   9.535000   9.522000

# %%
# Checking to see if country names match
exceptions = []
for country in list(df_full['Country'].unique()):
    if country in list(unemployment['Country Name'].unique()):
        continue
    else:
        exceptions.append(country)

print(exceptions)
# Out:
# []

# %%
# Merging unemployment data to df_full
df_full = pd.merge(df_full, unemployment, how='left', left_on='Country', right_on='Country Name')

# Renaming 2017 column to 2017_unemployment
df_full.rename(columns={'2017':'2017_unemployment'}, inplace=True)

# Dropping second 'Country Name' column
df_full.drop(columns=['Country Name','2018'], inplace=True)

# Sanity check
df_full.head()
# Out:
#    Country     Sex   Age  Edu_high  Edu_low  Pol_Ori  CMQ_1  CMQ_2  CMQ_3  \
# 0  Iceland    male  33.0       1.0      0.0      4.2   11.0   10.0    1.0
# 1  Iceland    male  28.0       1.0      0.0      4.2    7.0    7.0    4.0
# 2  Iceland  female  35.0       0.0      1.0      NaN    8.0    7.0    4.0
# 3  Iceland    male  55.0       1.0      0.0      5.0    5.0    8.0    6.0
# 4  Iceland    male  52.0       0.0      1.0      5.8    8.0    6.0    5.0
#
#    CMQ_4  CMQ_5  CM4x  CM5x  Winner_state  lrgen  lrecon  galtan  \
# 0    7.0    1.0  5.00   6.0           NaN    NaN     NaN     NaN
# 1    3.0    5.0  4.75   5.2           0.0    NaN     NaN     NaN
# 2    9.0    3.0  6.00   6.2           NaN    NaN     NaN     NaN
# 3    4.0    3.0  4.50   5.2           1.0    NaN     NaN     NaN
# 4    7.0    6.0  6.50   6.4           0.0    NaN     NaN     NaN
#
#        2017_GDP  2017_unemployment
# 0  2.472829e+10               2.74
# 1  2.472829e+10               2.74
# 2  2.472829e+10               2.74
# 3  2.472829e+10               2.74
# 4  2.472829e+10               2.74

# %%
df_full.groupby('Country')['2017_unemployment'].mean()
# Out:
# Country
# Austria                    5.50
# Belgium                    7.09
# Bosnia and Herzegovina    20.53
# Brazil                    12.93
# Croatia                   11.21
# Czechia                    2.89
# Denmark                    5.83
# France                     9.41
# Germany                    3.75
# Greece                    21.49
# Hungary                    4.16
# Iceland                    2.74
# Israel                     4.22
# Italy                     11.21
# Netherlands                4.84
# North Macedonia           22.81
# Norway                     4.16
# Poland                     4.89
# Portugal                   8.87
# Romania                    4.93
# Serbia                    13.48
# Spain                     17.22
# Sweden                     6.72
# Switzerland                4.80
# Turkiye                   10.82
# United Kingdom             4.33
# Name: 2017_unemployment, dtype: float64

# %%
df_full.corrwith(df_full['CM5x']).sort_values(ascending=False)
# Out:
# /var/folders/q2/xb4gqdn94tb91smj01xdsd040000gn/T/ipykernel_31365/1721921054.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_full.corrwith(df_full['CM5x']).sort_values(ascending=False)
# CM5x                 1.000000
# CM4x                 0.981278
# CMQ_4                0.856704
# CMQ_5                0.839009
# CMQ_3                0.764467
# CMQ_2                0.743323
# CMQ_1                0.726144
# 2017_unemployment    0.190922
# galtan               0.185199
# Edu_low              0.098357
# Pol_Ori              0.076524
# lrgen                0.058191
# Age                  0.005849
# lrecon              -0.036256
# 2017_GDP            -0.041772
# Winner_state        -0.148164
# Edu_high            -0.203212
# dtype: float64

# %%
democracy = pd.read_csv('data/democracy2017.csv')

democracy.head()
# Out:
#                   Country  Democracy_Score
# 0                 Austria                9
# 1                 Belgium                9
# 2  Bosnia and Herzegovina                6
# 3                  Brazil                7
# 4                 Croatia                7

# %%
# Merging democracy_score with df_full

df_full = pd.merge(df_full, democracy, left_on='Country', right_on='Country', how='left')

df_full.head()
# Out:
#    Country     Sex   Age  Edu_high  Edu_low  Pol_Ori  CMQ_1  CMQ_2  CMQ_3  \
# 0  Iceland    male  33.0       1.0      0.0      4.2   11.0   10.0    1.0
# 1  Iceland    male  28.0       1.0      0.0      4.2    7.0    7.0    4.0
# 2  Iceland  female  35.0       0.0      1.0      NaN    8.0    7.0    4.0
# 3  Iceland    male  55.0       1.0      0.0      5.0    5.0    8.0    6.0
# 4  Iceland    male  52.0       0.0      1.0      5.8    8.0    6.0    5.0
#
#    CMQ_4  CMQ_5  CM4x  CM5x  Winner_state  lrgen  lrecon  galtan  \
# 0    7.0    1.0  5.00   6.0           NaN    NaN     NaN     NaN
# 1    3.0    5.0  4.75   5.2           0.0    NaN     NaN     NaN
# 2    9.0    3.0  6.00   6.2           NaN    NaN     NaN     NaN
# 3    4.0    3.0  4.50   5.2           1.0    NaN     NaN     NaN
# 4    7.0    6.0  6.50   6.4           0.0    NaN     NaN     NaN
#
#        2017_GDP  2017_unemployment  Democracy_Score
# 0  2.472829e+10               2.74               10
# 1  2.472829e+10               2.74               10
# 2  2.472829e+10               2.74               10
# 3  2.472829e+10               2.74               10
# 4  2.472829e+10               2.74               10

# %%
df_full['CM5x'] = df_full['CM5x'] - 1

# %%
# Comparing democracy index and CM5x by country
democracy_by_country = df_full.groupby('Country')['Democracy_Score'].mean()
CM_by_country = df_full.groupby('Country')['CM5x'].mean()
democracy_sorted = pd.merge(democracy_by_country,CM_by_country, left_on='Country', right_on='Country').sort_values(by='Democracy_Score',ascending=False)
democracy_sorted
# Out:
#                         Democracy_Score      CM5x
# Country
# Iceland                            10.0  5.776786
# Sweden                             10.0  5.288577
# Denmark                            10.0  5.768523
# Austria                             9.0  5.671416
# Switzerland                         9.0  6.233907
# Spain                               9.0  6.934710
# Portugal                            9.0  7.067864
# Norway                              9.0  5.220638
# Netherlands                         9.0  4.683930
# Belgium                             9.0  6.353708
# Israel                              9.0  6.758852
# United Kingdom                      9.0  6.161259
# Germany                             9.0  5.548982
# France                              9.0  5.860592
# Czechia                             8.0  5.566234
# Romania                             8.0  6.735706
# Italy                               8.0  5.530330
# Greece                              7.0  6.274542
# North Macedonia                     7.0  6.466667
# Croatia                             7.0  6.447667
# Brazil                              7.0  6.418534
# Hungary                             6.0  6.672093
# Poland                              6.0  6.208488
# Serbia                              6.0  6.873796
# Bosnia and Herzegovina              6.0  6.664106
# Turkiye                             0.0  7.243731

# %%
# Plotting
plt.figure(figsize=(15,4))


# Creating plot
ax = sns.barplot(y=democracy_sorted.CM5x,
                 x=democracy_sorted.index,
                 hue=democracy_sorted.Democracy_Score,
                 palette='Blues',
                 width=.8,
                 dodge=False)

# Setting up colorbar
norm = plt.Normalize(democracy_sorted.Democracy_Score.min(), democracy_sorted.Democracy_Score.max())
sm = plt.cm.ScalarMappable(cmap="Blues", norm=norm)
cbar = plt.gca().figure.colorbar(sm, ax=plt.gca())
cbar.set_label('Economist Democracy Index')

# Plot parameters
sns.despine()
plt.ylim(4,7.5)
plt.xlabel(None)
plt.axhline(df_full['CM5x'].mean(), color='red', linestyle='--', alpha=.4, label='Mean Conspiracy Mentality')
plt.ylabel('Mean Conspiracy Mentality (Out of 10)')
plt.xticks(rotation=45,ha='right')
plt.legend().set_visible(False)
plt.title("Mean Conspiracy Mentality and Democracy Index by Country", fontsize=14)
plt.show()

# %%
# Comparing unemployment and CM5x by country
unemployment_by_country = df_full.groupby('Country')['2017_unemployment'].mean()
CM_by_country = df_full.groupby('Country')['CM5x'].mean()
unemployment_sorted = pd.merge(unemployment_by_country,CM_by_country, left_on='Country', right_on='Country').sort_values(by='2017_unemployment')
unemployment_sorted
# Out:
#                         2017_unemployment      CM5x
# Country
# Iceland                              2.74  5.776786
# Czechia                              2.89  5.566234
# Germany                              3.75  5.548982
# Norway                               4.16  5.220638
# Hungary                              4.16  6.672093
# Israel                               4.22  6.758852
# United Kingdom                       4.33  6.161259
# Switzerland                          4.80  6.233907
# Netherlands                          4.84  4.683930
# Poland                               4.89  6.208488
# Romania                              4.93  6.735706
# Austria                              5.50  5.671416
# Denmark                              5.83  5.768523
# Sweden                               6.72  5.288577
# Belgium                              7.09  6.353708
# Portugal                             8.87  7.067864
# France                               9.41  5.860592
# Turkiye                             10.82  7.243731
# Croatia                             11.21  6.447667
# Italy                               11.21  5.530330
# Brazil                              12.93  6.418534
# Serbia                              13.48  6.873796
# Spain                               17.22  6.934710
# Bosnia and Herzegovina              20.53  6.664106
# Greece                              21.49  6.274542
# North Macedonia                     22.81  6.466667

# %%
# Plotting
plt.figure(figsize=(15,4))


# Creating plot
ax = sns.barplot(y=unemployment_sorted.CM5x,
                 x=unemployment_sorted.index,
                 hue=unemployment_sorted['2017_unemployment'],
                 palette='Reds',
                 width=.8,
                 dodge=False)

# Setting up colorbar
norm = plt.Normalize(unemployment_sorted['2017_unemployment'].min(), unemployment_sorted['2017_unemployment'].max())
sm = plt.cm.ScalarMappable(cmap="Reds", norm=norm)
cbar = plt.gca().figure.colorbar(sm, ax=ax)
cbar.set_label('Unemployment Rate')

# Plot parameters
sns.despine()
plt.ylim(4,7.5)
plt.xlabel(None)
plt.axhline(df_full['CM5x'].mean(), color='red', linestyle='--', alpha=.4, label='Mean Conspiracy Mentality')
plt.ylabel('Mean Conspiracy Mentality (Out of 10)')
plt.xticks(rotation=45,ha='right')
plt.legend().set_visible(False)
plt.title("Mean Conspiracy Mentality and Unemployment Rate by Country", fontsize=14)
plt.show()

# %%
df_full.corrwith(df_full['CM5x']).sort_values(ascending=False)
# Out:
# /var/folders/q2/xb4gqdn94tb91smj01xdsd040000gn/T/ipykernel_31365/1721921054.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_full.corrwith(df_full['CM5x']).sort_values(ascending=False)
# CM5x                 1.000000
# CM4x                 0.981278
# CMQ_4                0.856704
# CMQ_5                0.839009
# CMQ_3                0.764467
# CMQ_2                0.743323
# CMQ_1                0.726144
# 2017_unemployment    0.190922
# galtan               0.185199
# Edu_low              0.098357
# Pol_Ori              0.076524
# lrgen                0.058191
# Age                  0.005849
# lrecon              -0.036256
# 2017_GDP            -0.041772
# Winner_state        -0.148164
# Democracy_Score     -0.160065
# Edu_high            -0.203212
# dtype: float64
